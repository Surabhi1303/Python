# %% [markdown]
# <a href="https://colab.research.google.com/github/Surabhi1303/Python/blob/master/HousePrice_Linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
df.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
df.corr()
# Out:
#                      Id  MSSubClass  LotFrontage  ...    MoSold    YrSold  SalePrice
# Id             1.000000    0.011156    -0.010601  ...  0.021172  0.000712  -0.021917
# MSSubClass     0.011156    1.000000    -0.386347  ... -0.013585 -0.021407  -0.084284
# LotFrontage   -0.010601   -0.386347     1.000000  ...  0.011200  0.007450   0.351799
# LotArea       -0.033226   -0.139781     0.426095  ...  0.001205 -0.014261   0.263843
# OverallQual   -0.028365    0.032628     0.251646  ...  0.070815 -0.027347   0.790982
# OverallCond    0.012609   -0.059316    -0.059213  ... -0.003511  0.043950  -0.077856
# YearBuilt     -0.012713    0.027850     0.123349  ...  0.012398 -0.013618   0.522897
# YearRemodAdd  -0.021998    0.040581     0.088866  ...  0.021490  0.035743   0.507101
# MasVnrArea    -0.050298    0.022936     0.193458  ... -0.005965 -0.008201   0.477493
# BsmtFinSF1    -0.005024   -0.069836     0.233633  ... -0.015727  0.014359   0.386420
# ...

# %%
df.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.isna().sum().sort_values()[df.isna().sum()>0]
# Out:
# Electrical         1
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# BsmtFinType2      38
# BsmtExposure      38
# GarageQual        81
# GarageFinish      81
# GarageYrBlt       81
# GarageType        81
# GarageCond        81
# LotFrontage      259
# FireplaceQu      690
# Fence           1179
# Alley           1369
# MiscFeature     1406
# PoolQC          1453
# dtype: int64

# %%
df.isna().sum().sort_values()[df.isna().sum()>0].plot(kind="bar")

# %%
df=df.drop(columns=["PoolQC","Alley","Fence","MiscFeature"])
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 77 columns]

# %%
df.isna().sum().sort_values()[df.isna().sum()>0].plot(kind="bar")

# %%
df.FireplaceQu.describe(include="all")
# Out:
# count     770
# unique      5
# top        Gd
# freq      380
# Name: FireplaceQu, dtype: object

# %%
df.FireplaceQu.value_counts()
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %%
df.loc[df.FireplaceQu.isna(),"FireplaceQu"]="NotDefined"

# %%
df.FireplaceQu.value_counts()
# Out:
# NotDefined    690
# Gd            380
# TA            313
# Fa             33
# Ex             24
# Po             20
# Name: FireplaceQu, dtype: int64

# %%
df.isna().sum()[df.isna().sum() > 0].sort_values().plot(kind="bar")

# %%
df.LotFrontage.describe()
# Out:
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
df.LotFrontage.hist()

# %%
df.LotFrontage.plot()

# %%
df.loc[df.LotFrontage.isna(), "LotFrontage"] = df.LotFrontage.mean()

# %%
df.isna().sum()[df.isna().sum() > 0].sort_values().plot(kind="bar")

# %%
garage_null_index = df.GarageYrBlt.isna()[df.GarageYrBlt.isna() == True].index
garage_null_index
# Out:
# Int64Index([  39,   48,   78,   88,   89,   99,  108,  125,  127,  140,  148,
#              155,  163,  165,  198,  210,  241,  250,  287,  291,  307,  375,
#              386,  393,  431,  434,  441,  464,  495,  520,  528,  533,  535,
#              562,  582,  613,  614,  620,  635,  636,  638,  649,  705,  710,
#              738,  750,  784,  826,  843,  921,  942,  954,  960,  968,  970,
#              976, 1009, 1011, 1030, 1038, 1096, 1123, 1131, 1137, 1143, 1173,
#             1179, 1218, 1219, 1234, 1257, 1283, 1323, 1325, 1326, 1337, 1349,
#             1407, 1449, 1450, 1453],
#            dtype='int64')

# %%
garage_null_index = df.GarageType.isna()[df.GarageType.isna() == True].index
garage_null_index
# Out:
# Int64Index([  39,   48,   78,   88,   89,   99,  108,  125,  127,  140,  148,
#              155,  163,  165,  198,  210,  241,  250,  287,  291,  307,  375,
#              386,  393,  431,  434,  441,  464,  495,  520,  528,  533,  535,
#              562,  582,  613,  614,  620,  635,  636,  638,  649,  705,  710,
#              738,  750,  784,  826,  843,  921,  942,  954,  960,  968,  970,
#              976, 1009, 1011, 1030, 1038, 1096, 1123, 1131, 1137, 1143, 1173,
#             1179, 1218, 1219, 1234, 1257, 1283, 1323, 1325, 1326, 1337, 1349,
#             1407, 1449, 1450, 1453],
#            dtype='int64')

# %%
df.loc[garage_null_index, :]
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 39      40          90       RL  ...        WD        AdjLand     82000
# 48      49         190       RM  ...       New        Partial    113000
# 78      79          90       RL  ...        WD         Normal    136500
# 88      89          50  C (all)  ...     ConLD        Abnorml     85000
# 89      90          20       RL  ...        WD         Normal    123600
# ...    ...         ...      ...  ...       ...            ...       ...
# 1349  1350          70       RM  ...        WD         Normal    122000
# 1407  1408          20       RL  ...        WD         Normal    112000
# 1449  1450         180       RM  ...        WD        Abnorml     92000
# 1450  1451          90       RL  ...        WD         Normal    136000
# 1453  1454          20       RL  ...        WD        Abnorml     84500
#
# [81 rows x 77 columns]

# %%
df = df.drop(index=garage_null_index)
df.shape
# Out:
# (1379, 77)

# %%
dfcorr=df.corr()

# %%
corr_salesprice = abs(dfcorr["SalePrice"])

# %%
corr_salesprice.sort_index()
# Out:
# 1stFlrSF         0.594935
# 2ndFlrSF         0.313336
# 3SsnPorch        0.039226
# BedroomAbvGr     0.164655
# BsmtFinSF1       0.375563
# BsmtFinSF2       0.023243
# BsmtFullBath     0.225988
# BsmtHalfBath     0.025651
# BsmtUnfSF        0.213135
# EnclosedPorch    0.120164
# Fireplaces       0.448877
# FullBath         0.556550
# GarageArea       0.608405
# GarageCars       0.637095
# GarageYrBlt      0.486362
# GrLivArea        0.708172
# HalfBath         0.270721
# Id               0.027636
# KitchenAbvGr     0.135574
# LotArea          0.252921
# LotFrontage      0.329314
# LowQualFinSF     0.008364
# MSSubClass       0.077707
# MasVnrArea       0.468083
# MiscVal          0.017933
# MoSold           0.043749
# OpenPorchSF      0.333036
# OverallCond      0.095278
# OverallQual      0.787228
# PoolArea         0.091518
# SalePrice        1.000000
# ScreenPorch      0.099453
# TotRmsAbvGrd     0.538309
# TotalBsmtSF      0.603583
# WoodDeckSF       0.312631
# ...

# %%
corr_salesprice[corr_salesprice>.55]
# Out:
# OverallQual    0.787228
# TotalBsmtSF    0.603583
# 1stFlrSF       0.594935
# GrLivArea      0.708172
# FullBath       0.556550
# GarageCars     0.637095
# GarageArea     0.608405
# SalePrice      1.000000
# Name: SalePrice, dtype: float64

# %%
Interetsing_cols = corr_salesprice[corr_salesprice > 0.55].index
Interetsing_cols
# Out:
# Index(['OverallQual', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath',
#        'GarageCars', 'GarageArea', 'SalePrice'],
#       dtype='object')

# %%
df2=df.loc[:,Interetsing_cols]
df2.head()
# Out:
#    OverallQual  TotalBsmtSF  1stFlrSF  ...  GarageCars  GarageArea  SalePrice
# 0            7          856       856  ...           2         548     208500
# 1            6         1262      1262  ...           2         460     181500
# 2            7          920       920  ...           2         608     223500
# 3            7          756       961  ...           3         642     140000
# 4            8         1145      1145  ...           3         836     250000
#
# [5 rows x 8 columns]

# %%
df2= df2.drop(columns=["GarageArea"])

# %%
df2.head()
# Out:
#    OverallQual  TotalBsmtSF  1stFlrSF  ...  FullBath  GarageCars  SalePrice
# 0            7          856       856  ...         2           2     208500
# 1            6         1262      1262  ...         2           2     181500
# 2            7          920       920  ...         2           2     223500
# 3            7          756       961  ...         1           3     140000
# 4            8         1145      1145  ...         2           3     250000
#
# [5 rows x 7 columns]

# %%
df2.describe()
# Out:
#        OverallQual  TotalBsmtSF  ...   GarageCars     SalePrice
# count  1379.000000  1379.000000  ...  1379.000000    1379.00000
# mean      6.187092  1074.445975  ...     1.870921  185479.51124
# std       1.345780   436.371874  ...     0.630055   79023.89060
# min       2.000000     0.000000  ...     1.000000   35311.00000
# 25%       5.000000   810.000000  ...     1.000000  134000.00000
# 50%       6.000000  1008.000000  ...     2.000000  167500.00000
# 75%       7.000000  1314.000000  ...     2.000000  217750.00000
# max      10.000000  6110.000000  ...     4.000000  755000.00000
#
# [8 rows x 7 columns]

# %%
df2.isna().sum()
# Out:
# OverallQual    0
# TotalBsmtSF    0
# 1stFlrSF       0
# GrLivArea      0
# FullBath       0
# GarageCars     0
# SalePrice      0
# dtype: int64

# %%
df2.boxplot()

# %%
df2.SalePrice.plot()

# %%
sns.heatmap(df2.corr(),cmap="Greens")

# %%
sns.distplot(df2.SalePrice)

# %%
q3=np.percentile(df2.SalePrice,25)
q1=np.percentile(df2.SalePrice,75)
iqr=q3-q1
ideal_max_pr=(1.5*iqr)+q3
ideal_max_pr
# Out:
# 8375.0

# %%
df2.SalePrice.plot()
plt.hlines(ideal_max_pr, 0, df2.shape[0])

# %%
df2.shape
# Out:
# (1379, 7)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X=df2.drop(columns=["SalePrice"])
Y=df2.SalePrice
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.8)
X_train.shape,X_test.shape
Y_train
# Out:
# 1403    282922
# 488     160000
# 1279     68400
# 991     168000
# 468     250000
#          ...
# 849     187000
# 432     122500
# 657     149000
# 1285    132500
# 389     426000
# Name: SalePrice, Length: 1103, dtype: int64

# %%
Y_train.shape,Y_test.shape
# Out:
# ((1103,), (276,))

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.coef_
# Out:
# array([ 2.51269786e+04,  2.23621690e+01,  1.18584420e+01,  4.50302521e+01,
#        -7.80327932e+02,  2.30643250e+04])

# %%
lr.intercept_
# Out:
# -118787.569773475

# %%
Y_predict=lr.predict(X_test)

# %%
Y_test.reset_index(drop=True).plot()

# %%
Y_test.reset_index(drop=True).plot()
pd.DataFrame(Y_predict,columns=["Pred_Saleprice"]).plot()

# %%
Y_test=Y_test.reset_index(drop=True)
Y_test
# Out:
# 0      437154
# 1      220000
# 2      250000
# 3      250580
# 4      216837
#         ...
# 271    174000
# 272    144152
# 273    212000
# 274    123000
# 275    250000
# Name: SalePrice, Length: 276, dtype: int64

# %%
pd.DataFrame(Y_predict,columns=["Pred_Salesprice"])
Y_predict
# Out:
# array([361069.77399777, 228856.86912382, 206850.44306166, 210401.4590057 ,
#        247710.55158671, 112648.22990017, 244225.63695504, 111562.42011217,
#        287037.40777134, 222526.84107499,  83208.85914335, 205519.70317915,
#        245977.37087157,  85274.52629778, 131715.82712   , 101408.10763418,
#        308362.3047031 ,  99196.9496369 , 194873.9775284 , 261520.5895633 ,
#        154243.30724289, 167018.9480356 , 312007.84441021, 188360.8090571 ,
#        202559.69392257, 199601.45349915, 129395.24566499, 239090.27148338,
#         47350.10895359,  76178.27046029, 274363.68439115, 187639.82557828,
#        172900.35762793, 160749.08914437, 308442.49511671, 200612.81158037,
#        282845.65794823, 156811.23979425, 168261.75918891, 267614.09876683,
#         95856.28482053, 152846.37283947, 180391.29566741, 131290.13804961,
#        215473.51425037, 197965.18855581,  82981.82271852, 295369.0907573 ,
# ...

# %%
pd.DataFrame(Y_predict,columns=["Pred_Salesprice"])
sns.regplot(Y_test,Y_predict)

# %%
from sklearn.metrics import mean_squared_error
import math
#RMC
mean_squared_error(Y_test, Y_predict)**0.5
# Out:
# 39486.08529908656

# %%
Y_test=Y_test.reset_index()
Y_test.SalePrice
# Out:
# 0      437154
# 1      220000
# 2      250000
# 3      250580
# 4      216837
#         ...
# 271    174000
# 272    144152
# 273    212000
# 274    123000
# 275    250000
# Name: SalePrice, Length: 276, dtype: int64

# %%
Y_predict=pd.DataFrame(Y_predict,columns=["Pred_Salesprice"])

# %%
Y_test.SalePrice.plot(label= "Original")
Y_predict.Pred_Salesprice.plot(label = "Predicted")
plt.legend()

# %%
import pickle as pk1
pk1.dump(lr,open("LINEAR.pk1","wb"))
